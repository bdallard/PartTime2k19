# %%
#import du package avec as 
import MonPackage as mp 
#import d'un script spécifique 
from MonPackage import operation

# %%
operation.ajoute_deux(2)
# Out:
# 4

# %%
mp.operation.ajoute_deux(6)
# Out:
# 8
