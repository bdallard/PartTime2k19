# %% [markdown]
# # PCA Introduction

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
#+autres

# %% [markdown]
# ### En utilisant la fonction `make_blobs` générer un dataset de shape (100,10)

# %%
# Out:
# (100, 10)

# %% [markdown]
# ### Afficher une représentation graphique du dataset

# %% [markdown]
# ### Instancier un objet `PCA(n_components=4)`

# %% [markdown]
# ### Construire un dataFrame avec les 4axes ainsi que les clusters

# %%
# Out:
#          PC1        PC2       PC3       PC4  Cluster
# 0  -8.133443  -0.302138  9.984672  0.423878        2
# 1  18.931381   0.193838  0.045462 -3.894042        1
# 2  -6.571463 -14.188490 -3.120115  1.278588        0
# 3  -7.533948  14.439427 -5.443487  3.358252        3
# 4  -4.591760 -11.315284 -9.130630 -1.420151        0

# %% [markdown]
# ### Afficher le ratio de variance expliquée

# %%
# Out:
# array([0.41594854, 0.3391866 , 0.1600729 , 0.02016822])

# %% [markdown]
# ### Afficher le ratio de variance expliquée par axe

# %% [markdown]
# ### Afficher les clusters des 2 premiers axes
