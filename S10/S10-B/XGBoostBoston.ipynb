# %% [markdown]
# # Extreme Gradient Boosting XGBoost x Boston
# Importer le dataset boston de sklearn

# %%
import xgboost as xgb
import pandas as pd 
import numpy as np 
#+autres

# %% [markdown]
# ### Importer les data dans un DataFrame

# %%
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ### Faite de même avec la target

# %% [markdown]
# ### Afficher les information mémoire du dataset

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# PRICE      506 non-null float64
# dtypes: float64(14)
# memory usage: 55.4 KB

# %% [markdown]
# ### Construire les variables de travail (X,y)

# %% [markdown]
# ### Convertir vos variables en objet `DMatrix`

# %% [markdown]
# ### Effectuez un split

# %% [markdown]
# ### Instancier un objet `XGBRegressor`

# %%
# Out:
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.3, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=10, n_jobs=1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=1)

# %% [markdown]
# ### Faire un `fit`

# %% [markdown]
# ### Calculer l'erreur moyenne RMSE `Root Mean Square Error`

# %%
# Out:
# RMSE: 10.549667698529078

# %% [markdown]
# ### Instancier un objet `Cross-validation` avec les paramètres suivants
# ```
# params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1, 'max_depth': 5, 'alpha': 10}
#
# ```

# %%
# Out:
#     train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         21.652929        0.038264       21.670776       0.072370
# 1         19.738335        0.096610       19.779675       0.022115
# 2         17.985388        0.118166       18.077801       0.072426
# 3         16.475789        0.114711       16.586770       0.103876
# 4         14.996755        0.104659       15.152030       0.103398
# 5         13.692208        0.092568       13.872738       0.068876
# 6         12.536402        0.108459       12.728972       0.085386
# 7         11.549877        0.095359       11.777126       0.111292
# 8         10.643629        0.102855       10.907334       0.108743
# 9          9.783324        0.077239       10.091054       0.054810
# 10         9.008263        0.070765        9.386985       0.045446
# 11         8.313372        0.081678        8.731271       0.036727
# 12         7.769609        0.088022        8.230040       0.043842
# ...

# %% [markdown]
# ### Afficher les résultats de la `Cross-validation`

# %%
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0        21.652929        0.038264       21.670776       0.072370
# 1        19.738335        0.096610       19.779675       0.022115
# 2        17.985388        0.118166       18.077801       0.072426
# 3        16.475789        0.114711       16.586770       0.103876
# 4        14.996755        0.104659       15.152030       0.103398

# %% [markdown]
# ### Entrainer votre booster avec les paramètres ci-dessus

# %% [markdown]
# ### Afficher le 4ème arbre via la fonction `plot_tree`

# %% [markdown]
# ### Afficher les features importance
